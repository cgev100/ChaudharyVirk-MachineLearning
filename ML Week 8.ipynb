# %%
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
# check for GPU availability things
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15448143331949246433
# xla_global_id: -1
# ]

# %%
import pandas as pd
# diagnosis file converted from txt to csv
diagnosis = pd.read_csv(r'C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_Challenge_diagnosis.csv')
diagnosis
# Out:
#       ID    Symptom
# 0    101       URTI
# 1    102    Healthy
# 2    103     Asthma
# 3    104       COPD
# 4    105       URTI
# ..   ...        ...
# 121  222       COPD
# 122  223       COPD
# 123  224    Healthy
# 124  225    Healthy
# 125  226  Pneumonia
#
# [126 rows x 2 columns]

# %%
diag = diagnosis.to_dict()
ids=list(diag['ID'].values())
print('Number of instances: ',len(ids))
symp=list(diag['Symptom'].values())
# Out:
# Number of instances:  126

# %%
pip  install -c conda-forge librosa
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'conda-forge'

# %%
 # Audio feature extraction library
import librosa
import librosa.display
#file name
import glob

# %%
import glob
import librosa
import pandas as pd

# Assuming ids and symp are defined earlier
dataset = []

for filename in glob.iglob(r'C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\*'):
    if filename.endswith('.wav'):
        try:
            identity = filename.split('\\')[-1][:3]  # Using \ for Windows paths
            index = ids.index(int(identity))
            label = symp[index]
            duration = librosa.get_duration(filename=filename)

            if duration >= 3:
                slice_size = 3
                iterations = int((duration - slice_size) / (slice_size - 1))
                iterations += 1
                initial_offset = (duration - ((iterations * (slice_size - 1)) + 1)) / 2

                for i in range(iterations):
                    offset = initial_offset + i * (slice_size - 1)
                    dataset.append({"filename": filename, "label": label, "offset": offset})
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# Create the DataFrame
dataset = pd.DataFrame(dataset)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8965 entries, 0 to 8964
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  8965 non-null   object
#  1   label     8965 non-null   object
#  2   offset    8965 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 210.2+ KB

# %%
dataset.head()
# Out:
#                                             filename label  offset
# 0  C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_fin...  URTI     0.5
# 1  C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_fin...  URTI     2.5
# 2  C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_fin...  URTI     4.5
# 3  C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_fin...  URTI     6.5
# 4  C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_fin...  URTI     8.5

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(4,6))
dataset.label.value_counts().plot(kind='bar', title="Dataset distribution")
plt.show()

# %%
from sklearn.model_selection import train_test_split
import numpy as np
train, test = train_test_split(dataset, test_size=0.2, random_state=42)
print("Train: %i" % len(train))
print("Test: %i" % len(test))
# Out:
# Train: 7172
# Test: 1793

# %%
plt.figure(figsize=(20,40))
idx = 0
for label in dataset.label.unique():
    y, sr = librosa.load(dataset[dataset.label==label].filename.iloc[1],duration=3)
    print(dataset[dataset.label==label].filename.iloc[1])
    idx+=1
    plt.subplot(8, 3, idx)
    plt.title("%s waveplot" % label)
    librosa.display.waveshow(y, sr=sr)

    idx+=1
    plt.subplot(8, 3, idx)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    S_DB = librosa.power_to_db(S, ref=np.max)
    librosa.display.specshow(S_DB, sr=sr, hop_length=512, x_axis='time',y_axis='mel')
    plt.title("%s mel spectogram" % label)
    
    idx+=1
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)
    plt.subplot(8, 3, idx)
    librosa.display.specshow(mfccs, x_axis='time')
    plt.title("%s mfcc(Mel Spectrogram)" % label)
plt.show()
# Out:
# C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\101_1b1_Al_sc_Meditron.wav
# C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\102_1b1_Ar_sc_Meditron.wav
# C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\103_2b2_Ar_mc_LittC2SE.wav
# C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\104_1b1_Al_sc_Litt3200.wav
# C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\108_1b1_Al_sc_Meditron.wav
# C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\111_1b2_Tc_sc_Meditron.wav
# C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\122_2b1_Al_mc_LittC2SE.wav
# C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\149_1b1_Al_sc_Meditron.wav

# %%
def extract_features(audio_path,offset):
    y, sr = librosa.load(audio_path, offset=offset, duration=3)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048,
    hop_length=512,
    n_mels=128)
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)
    # mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
    return mfccs

# %%
from tqdm import tqdm

# %%
x_train = []
x_test = []

# Extract features for training set
for idx in tqdm(range(len(train))):
    x_train.append(extract_features(train.filename.iloc[idx], train.offset.iloc[idx]))

# Extract features for test set
for idx in tqdm(range(len(test))):
    x_test.append(extract_features(test.filename.iloc[idx], test.offset.iloc[idx]))

# Convert the lists of features to numpy arrays
x_train = np.asarray(x_train)
x_test = np.asarray(x_test)

# Print the shapes of the feature arrays
print("X train shape:", x_train.shape)
print("X test shape:", x_test.shape)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 7172/7172 [00:59<00:00, 119.62it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1793/1793 [00:13<00:00, 129.89it/s]
# X train shape: (7172, 40, 130)
# X test shape: (1793, 40, 130)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight

from tensorflow.keras.utils import to_categorical

# %%
encoder = LabelEncoder()
encoder.fit(train.label)
y_train = encoder.transform(train.label)
y_test = encoder.transform(test.label)
# Compute class weights
class_weights = class_weight.compute_class_weight(class_weight='balanced',classes = np.unique(y_train),y=y_train)

# %%
class_weights
# Out:
# array([128.07142857,   8.15      ,   8.965     ,   0.14341705,
#          3.46138996,  56.03125   ,   3.4348659 ,   5.33630952])

# %%
weight = {i : class_weights[i] for i in range(8)}
weight
# Out:
# {0: 128.07142857142858,
#  1: 8.15,
#  2: 8.965,
#  3: 0.14341705327147655,
#  4: 3.4613899613899615,
#  5: 56.03125,
#  6: 3.4348659003831417,
#  7: 5.336309523809524}

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2],1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
print("X train:", x_train.shape)
print("Y train:", y_train.shape)
print("X test:", x_test.shape)
print("Y test:", y_test.shape)
# Out:
# X train: (7172, 40, 130, 1)
# Y train: (7172, 8)
# X test: (1793, 40, 130, 1)
# Y test: (1793, 8)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, Conv2D, MaxPooling2D,GlobalAveragePooling2D

# %%
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, input_shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.5))
model.add(GlobalAveragePooling2D())
model.add(Dense(len(encoder.classes_), activation='softmax'))
#Visualise the structure
model.summary()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 39, 129, 16)         │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 19, 64, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 19, 64, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 18, 63, 32)          │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 9, 31, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 9, 31, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 30, 64)           │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 15, 64)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 15, 64)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 3, 14, 128)          │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 1, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │           1,032 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 44,344 (173.22 KB)
#  Trainable params: 44,344 (173.22 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

# %%
history = model.fit(x_train, y_train,
batch_size=128,
epochs=300,validation_data=(x_test, y_test),
shuffle=True, class_weight=weight)
# Out:
# Epoch 1/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.7432 - loss: 0.8749 - val_accuracy: 0.8472 - val_loss: 0.4881
# Epoch 2/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.7275 - loss: 0.9759 - val_accuracy: 0.7791 - val_loss: 0.6757
# Epoch 3/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.7062 - loss: 0.8911 - val_accuracy: 0.8583 - val_loss: 0.4184
# Epoch 4/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.7457 - loss: 0.7757 - val_accuracy: 0.8450 - val_loss: 0.4753
# Epoch 5/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.7777 - loss: 0.8138 - val_accuracy: 0.8410 - val_loss: 0.4545
# Epoch 6/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.7575 - loss: 0.9241 - val_accuracy: 0.8477 - val_loss: 0.4382
# Epoch 7/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.7446 - loss: 0.6702 - val_accuracy: 0.8572 - val_loss: 0.4025
# Epoch 8/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.7830 - loss: 0.6456 - val_accuracy: 0.8684 - val_loss: 0.3904
# Epoch 9/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.7775 - loss: 0.6899 - val_accuracy: 0.8779 - val_loss: 0.3608
# Epoch 10/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7796 - loss: 0.6623 - val_accuracy: 0.8946 - val_loss: 0.2988
# Epoch 11/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.8022 - loss: 0.6714 - val_accuracy: 0.8706 - val_loss: 0.3796
# Epoch 12/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.7945 - loss: 0.5853 - val_accuracy: 0.8182 - val_loss: 0.4918
# Epoch 13/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8031 - loss: 0.6320 - val_accuracy: 0.8226 - val_loss: 0.4896
# Epoch 14/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.7498 - loss: 0.6688 - val_accuracy: 0.8544 - val_loss: 0.4237
# Epoch 15/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.7710 - loss: 0.5348 - val_accuracy: 0.8483 - val_loss: 0.4279
# Epoch 16/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8357 - loss: 0.5312 - val_accuracy: 0.8996 - val_loss: 0.2880
# Epoch 17/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8366 - loss: 0.5586 - val_accuracy: 0.8249 - val_loss: 0.5179
# Epoch 18/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.8155 - loss: 0.5720 - val_accuracy: 0.8438 - val_loss: 0.4333
# Epoch 19/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8326 - loss: 0.4420 - val_accuracy: 0.8544 - val_loss: 0.4350
# Epoch 20/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8364 - loss: 0.4851 - val_accuracy: 0.8338 - val_loss: 0.4371
# Epoch 21/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8329 - loss: 0.4422 - val_accuracy: 0.8745 - val_loss: 0.3284
# Epoch 22/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8256 - loss: 0.4322 - val_accuracy: 0.8806 - val_loss: 0.3319
# Epoch 23/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.7321 - loss: 0.6294 - val_accuracy: 0.8818 - val_loss: 0.3306
# Epoch 24/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.8438 - loss: 0.4492 - val_accuracy: 0.8918 - val_loss: 0.3271
# Epoch 25/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8437 - loss: 0.5170 - val_accuracy: 0.8494 - val_loss: 0.4358
# Epoch 26/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8405 - loss: 0.4388 - val_accuracy: 0.8862 - val_loss: 0.3167
# Epoch 27/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8742 - loss: 0.3480 - val_accuracy: 0.8840 - val_loss: 0.3255
# Epoch 28/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8564 - loss: 0.3503 - val_accuracy: 0.8812 - val_loss: 0.3353
# Epoch 29/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8608 - loss: 0.3379 - val_accuracy: 0.9057 - val_loss: 0.2565
# Epoch 30/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8506 - loss: 0.5613 - val_accuracy: 0.9085 - val_loss: 0.2663
# Epoch 31/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.8751 - loss: 0.3246 - val_accuracy: 0.9080 - val_loss: 0.2739
# Epoch 32/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.8768 - loss: 0.3467 - val_accuracy: 0.8834 - val_loss: 0.3764
# Epoch 33/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8680 - loss: 0.3933 - val_accuracy: 0.9113 - val_loss: 0.2597
# Epoch 34/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.8904 - loss: 0.3427 - val_accuracy: 0.8784 - val_loss: 0.3092
# Epoch 35/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.8806 - loss: 0.3182 - val_accuracy: 0.9069 - val_loss: 0.2749
# Epoch 36/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.8796 - loss: 0.3488 - val_accuracy: 0.9175 - val_loss: 0.2533
# Epoch 37/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8856 - loss: 0.2729 - val_accuracy: 0.9297 - val_loss: 0.1851
# Epoch 38/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.8814 - loss: 0.3338 - val_accuracy: 0.9096 - val_loss: 0.2623
# Epoch 39/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8756 - loss: 0.3133 - val_accuracy: 0.9080 - val_loss: 0.2654
# Epoch 40/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8867 - loss: 0.2887 - val_accuracy: 0.9381 - val_loss: 0.1792
# Epoch 41/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9205 - loss: 0.2018 - val_accuracy: 0.9320 - val_loss: 0.1972
# Epoch 42/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9103 - loss: 0.2193 - val_accuracy: 0.9375 - val_loss: 0.1643
# Epoch 43/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9007 - loss: 0.2852 - val_accuracy: 0.9175 - val_loss: 0.2355
# Epoch 44/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8947 - loss: 0.2814 - val_accuracy: 0.9253 - val_loss: 0.2077
# Epoch 45/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9050 - loss: 0.2191 - val_accuracy: 0.9052 - val_loss: 0.2766
# Epoch 46/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8844 - loss: 0.2112 - val_accuracy: 0.9202 - val_loss: 0.2155
# Epoch 47/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.8994 - loss: 0.2463 - val_accuracy: 0.8885 - val_loss: 0.3202
# Epoch 48/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9009 - loss: 0.2515 - val_accuracy: 0.9414 - val_loss: 0.1696
# Epoch 49/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9128 - loss: 0.2157 - val_accuracy: 0.9281 - val_loss: 0.1839
# Epoch 50/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9037 - loss: 0.2156 - val_accuracy: 0.9269 - val_loss: 0.2187
# Epoch 51/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.8977 - loss: 0.2297 - val_accuracy: 0.9364 - val_loss: 0.1811
# Epoch 52/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.8856 - loss: 0.2846 - val_accuracy: 0.9420 - val_loss: 0.1644
# Epoch 53/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.9105 - loss: 0.2065 - val_accuracy: 0.9269 - val_loss: 0.2078
# Epoch 54/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.8941 - loss: 0.2557 - val_accuracy: 0.9314 - val_loss: 0.1760
# Epoch 55/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9097 - loss: 0.2173 - val_accuracy: 0.9320 - val_loss: 0.1762
# Epoch 56/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9078 - loss: 0.2110 - val_accuracy: 0.9320 - val_loss: 0.1964
# Epoch 57/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9068 - loss: 0.2318 - val_accuracy: 0.9353 - val_loss: 0.1773
# Epoch 58/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9216 - loss: 0.1725 - val_accuracy: 0.9253 - val_loss: 0.2106
# Epoch 59/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9065 - loss: 0.2031 - val_accuracy: 0.9214 - val_loss: 0.2384
# Epoch 60/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9212 - loss: 0.1480 - val_accuracy: 0.9119 - val_loss: 0.2320
# Epoch 61/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9135 - loss: 0.2251 - val_accuracy: 0.9498 - val_loss: 0.1412
# Epoch 62/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9245 - loss: 0.1975 - val_accuracy: 0.9347 - val_loss: 0.1707
# Epoch 63/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.9098 - loss: 0.1735 - val_accuracy: 0.9359 - val_loss: 0.2047
# Epoch 64/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - accuracy: 0.9143 - loss: 0.1734 - val_accuracy: 0.9437 - val_loss: 0.1596
# Epoch 65/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9206 - loss: 0.1584 - val_accuracy: 0.9186 - val_loss: 0.2091
# Epoch 66/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8885 - loss: 0.2455 - val_accuracy: 0.9197 - val_loss: 0.2095
# Epoch 67/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9102 - loss: 0.1693 - val_accuracy: 0.9136 - val_loss: 0.2353
# Epoch 68/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9134 - loss: 0.1794 - val_accuracy: 0.9543 - val_loss: 0.1356
# Epoch 69/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9409 - loss: 0.1350 - val_accuracy: 0.9426 - val_loss: 0.1454
# Epoch 70/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9312 - loss: 0.1519 - val_accuracy: 0.9498 - val_loss: 0.1313
# Epoch 71/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9234 - loss: 0.1624 - val_accuracy: 0.9347 - val_loss: 0.1678
# Epoch 72/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9369 - loss: 0.1391 - val_accuracy: 0.9186 - val_loss: 0.2223
# Epoch 73/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9326 - loss: 0.1621 - val_accuracy: 0.9375 - val_loss: 0.1846
# Epoch 74/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9067 - loss: 0.1640 - val_accuracy: 0.9024 - val_loss: 0.3016
# Epoch 75/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9097 - loss: 0.2352 - val_accuracy: 0.9353 - val_loss: 0.1879
# Epoch 76/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9181 - loss: 0.1681 - val_accuracy: 0.9292 - val_loss: 0.1868
# Epoch 77/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9251 - loss: 0.1596 - val_accuracy: 0.9492 - val_loss: 0.1396
# Epoch 78/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9161 - loss: 0.1765 - val_accuracy: 0.9124 - val_loss: 0.2554
# Epoch 79/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9162 - loss: 0.1613 - val_accuracy: 0.9269 - val_loss: 0.2123
# Epoch 80/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9322 - loss: 0.1187 - val_accuracy: 0.9381 - val_loss: 0.1845
# Epoch 81/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9385 - loss: 0.1187 - val_accuracy: 0.9537 - val_loss: 0.1241
# Epoch 82/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9413 - loss: 0.1285 - val_accuracy: 0.9286 - val_loss: 0.2066
# Epoch 83/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9201 - loss: 0.1216 - val_accuracy: 0.9504 - val_loss: 0.1379
# Epoch 84/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9445 - loss: 0.1004 - val_accuracy: 0.9364 - val_loss: 0.1853
# Epoch 85/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9355 - loss: 0.1102 - val_accuracy: 0.9414 - val_loss: 0.1770
# Epoch 86/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9441 - loss: 0.1286 - val_accuracy: 0.9331 - val_loss: 0.2023
# Epoch 87/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9318 - loss: 0.1265 - val_accuracy: 0.9459 - val_loss: 0.1686
# Epoch 88/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.8972 - loss: 0.2515 - val_accuracy: 0.9403 - val_loss: 0.1629
# Epoch 89/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9285 - loss: 0.1200 - val_accuracy: 0.9281 - val_loss: 0.2001
# Epoch 90/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9299 - loss: 0.1216 - val_accuracy: 0.9230 - val_loss: 0.2117
# Epoch 91/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9131 - loss: 0.2253 - val_accuracy: 0.9492 - val_loss: 0.1457
# Epoch 92/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.8915 - loss: 0.2509 - val_accuracy: 0.9520 - val_loss: 0.1355
# Epoch 93/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9203 - loss: 0.1950 - val_accuracy: 0.9398 - val_loss: 0.1628
# Epoch 94/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9386 - loss: 0.1286 - val_accuracy: 0.9364 - val_loss: 0.1667
# Epoch 95/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9442 - loss: 0.0985 - val_accuracy: 0.9241 - val_loss: 0.1979
# Epoch 96/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9390 - loss: 0.1010 - val_accuracy: 0.9269 - val_loss: 0.2022
# Epoch 97/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9351 - loss: 0.1371 - val_accuracy: 0.9481 - val_loss: 0.1496
# Epoch 98/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9432 - loss: 0.1010 - val_accuracy: 0.9543 - val_loss: 0.1224
# Epoch 99/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9513 - loss: 0.0896 - val_accuracy: 0.9431 - val_loss: 0.1343
# Epoch 100/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9553 - loss: 0.0796 - val_accuracy: 0.9347 - val_loss: 0.1753
# Epoch 101/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9335 - loss: 0.1060 - val_accuracy: 0.9158 - val_loss: 0.2398
# Epoch 102/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8901 - loss: 0.1804 - val_accuracy: 0.9403 - val_loss: 0.1723
# Epoch 103/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9296 - loss: 0.1339 - val_accuracy: 0.9426 - val_loss: 0.1692
# Epoch 104/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9432 - loss: 0.1110 - val_accuracy: 0.9543 - val_loss: 0.1380
# Epoch 105/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9455 - loss: 0.1065 - val_accuracy: 0.9453 - val_loss: 0.1500
# Epoch 106/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9463 - loss: 0.0840 - val_accuracy: 0.9331 - val_loss: 0.1727
# Epoch 107/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9271 - loss: 0.1010 - val_accuracy: 0.9593 - val_loss: 0.1173
# Epoch 108/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9515 - loss: 0.0860 - val_accuracy: 0.9520 - val_loss: 0.1213
# Epoch 109/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9407 - loss: 0.1147 - val_accuracy: 0.9498 - val_loss: 0.1294
# Epoch 110/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9530 - loss: 0.0965 - val_accuracy: 0.9281 - val_loss: 0.2091
# Epoch 111/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9085 - loss: 0.2334 - val_accuracy: 0.9465 - val_loss: 0.1332
# Epoch 112/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9216 - loss: 0.1501 - val_accuracy: 0.9526 - val_loss: 0.1105
# Epoch 113/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9404 - loss: 0.1222 - val_accuracy: 0.9108 - val_loss: 0.2488
# Epoch 114/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.8818 - loss: 0.2927 - val_accuracy: 0.9492 - val_loss: 0.1377
# Epoch 115/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9408 - loss: 0.0942 - val_accuracy: 0.9347 - val_loss: 0.1817
# Epoch 116/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9210 - loss: 0.1493 - val_accuracy: 0.9448 - val_loss: 0.1634
# Epoch 117/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9405 - loss: 0.0922 - val_accuracy: 0.9387 - val_loss: 0.1695
# Epoch 118/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9326 - loss: 0.0977 - val_accuracy: 0.9509 - val_loss: 0.1354
# Epoch 119/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9422 - loss: 0.1131 - val_accuracy: 0.9498 - val_loss: 0.1389
# Epoch 120/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9516 - loss: 0.0877 - val_accuracy: 0.9292 - val_loss: 0.2176
# Epoch 121/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9376 - loss: 0.1051 - val_accuracy: 0.9610 - val_loss: 0.1061
# Epoch 122/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9576 - loss: 0.0741 - val_accuracy: 0.9392 - val_loss: 0.1744
# Epoch 123/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9472 - loss: 0.0901 - val_accuracy: 0.9615 - val_loss: 0.1023
# Epoch 124/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9508 - loss: 0.1119 - val_accuracy: 0.9576 - val_loss: 0.1107
# Epoch 125/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9537 - loss: 0.0642 - val_accuracy: 0.9297 - val_loss: 0.1937
# Epoch 126/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9132 - loss: 0.2087 - val_accuracy: 0.9147 - val_loss: 0.2372
# Epoch 127/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9380 - loss: 0.1003 - val_accuracy: 0.9320 - val_loss: 0.1960
# Epoch 128/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9359 - loss: 0.1011 - val_accuracy: 0.9537 - val_loss: 0.1381
# Epoch 129/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9425 - loss: 0.1334 - val_accuracy: 0.9470 - val_loss: 0.1267
# Epoch 130/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9473 - loss: 0.1010 - val_accuracy: 0.9576 - val_loss: 0.1222
# Epoch 131/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9454 - loss: 0.0797 - val_accuracy: 0.9671 - val_loss: 0.0914
# Epoch 132/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9519 - loss: 0.0781 - val_accuracy: 0.9431 - val_loss: 0.1674
# Epoch 133/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9515 - loss: 0.1011 - val_accuracy: 0.9582 - val_loss: 0.1162
# Epoch 134/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9553 - loss: 0.0740 - val_accuracy: 0.9587 - val_loss: 0.1117
# Epoch 135/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9518 - loss: 0.0807 - val_accuracy: 0.9548 - val_loss: 0.1201
# Epoch 136/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9404 - loss: 0.1126 - val_accuracy: 0.9197 - val_loss: 0.2397
# Epoch 137/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9254 - loss: 0.1275 - val_accuracy: 0.9387 - val_loss: 0.1643
# Epoch 138/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9219 - loss: 0.0945 - val_accuracy: 0.9537 - val_loss: 0.1345
# Epoch 139/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9551 - loss: 0.0725 - val_accuracy: 0.9637 - val_loss: 0.0895
# Epoch 140/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9577 - loss: 0.0592 - val_accuracy: 0.9359 - val_loss: 0.1775
# Epoch 141/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9496 - loss: 0.0648 - val_accuracy: 0.9571 - val_loss: 0.1171
# Epoch 142/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9539 - loss: 0.0796 - val_accuracy: 0.9632 - val_loss: 0.0900
# Epoch 143/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9410 - loss: 0.0938 - val_accuracy: 0.9102 - val_loss: 0.2667
# Epoch 144/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9209 - loss: 0.1500 - val_accuracy: 0.9476 - val_loss: 0.1448
# Epoch 145/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9436 - loss: 0.1493 - val_accuracy: 0.9520 - val_loss: 0.1399
# Epoch 146/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9541 - loss: 0.0885 - val_accuracy: 0.9576 - val_loss: 0.1084
# Epoch 147/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.9572 - loss: 0.0810 - val_accuracy: 0.9576 - val_loss: 0.1233
# Epoch 148/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9497 - loss: 0.0689 - val_accuracy: 0.9598 - val_loss: 0.1132
# Epoch 149/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9576 - loss: 0.0569 - val_accuracy: 0.9604 - val_loss: 0.1066
# Epoch 150/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9371 - loss: 0.1338 - val_accuracy: 0.9080 - val_loss: 0.3000
# Epoch 151/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9135 - loss: 0.2138 - val_accuracy: 0.9398 - val_loss: 0.1675
# Epoch 152/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9376 - loss: 0.1312 - val_accuracy: 0.9253 - val_loss: 0.1896
# Epoch 153/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.9362 - loss: 0.0948 - val_accuracy: 0.9509 - val_loss: 0.1327
# Epoch 154/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9424 - loss: 0.0611 - val_accuracy: 0.9559 - val_loss: 0.1246
# Epoch 155/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9334 - loss: 0.1226 - val_accuracy: 0.9643 - val_loss: 0.0940
# Epoch 156/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9548 - loss: 0.0679 - val_accuracy: 0.9554 - val_loss: 0.1003
# Epoch 157/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9440 - loss: 0.0870 - val_accuracy: 0.9621 - val_loss: 0.0931
# Epoch 158/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9468 - loss: 0.0780 - val_accuracy: 0.9671 - val_loss: 0.0935
# Epoch 159/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9608 - loss: 0.0546 - val_accuracy: 0.9559 - val_loss: 0.1182
# Epoch 160/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9465 - loss: 0.0731 - val_accuracy: 0.9621 - val_loss: 0.0907
# Epoch 161/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9640 - loss: 0.0614 - val_accuracy: 0.9520 - val_loss: 0.1294
# Epoch 162/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9551 - loss: 0.0750 - val_accuracy: 0.9649 - val_loss: 0.1014
# Epoch 163/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9439 - loss: 0.1456 - val_accuracy: 0.9426 - val_loss: 0.1577
# Epoch 164/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9492 - loss: 0.0788 - val_accuracy: 0.9632 - val_loss: 0.1035
# Epoch 165/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9601 - loss: 0.0496 - val_accuracy: 0.9649 - val_loss: 0.0890
# Epoch 166/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9560 - loss: 0.0782 - val_accuracy: 0.9654 - val_loss: 0.0889
# Epoch 167/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9666 - loss: 0.0599 - val_accuracy: 0.9437 - val_loss: 0.1546
# Epoch 168/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9602 - loss: 0.0653 - val_accuracy: 0.9559 - val_loss: 0.1233
# Epoch 169/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8069 - loss: 0.8479 - val_accuracy: 0.8974 - val_loss: 0.2737
# Epoch 170/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.8893 - loss: 0.2097 - val_accuracy: 0.9453 - val_loss: 0.1742
# Epoch 171/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9400 - loss: 0.1353 - val_accuracy: 0.9236 - val_loss: 0.2230
# Epoch 172/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9291 - loss: 0.1156 - val_accuracy: 0.9375 - val_loss: 0.1595
# Epoch 173/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9399 - loss: 0.1163 - val_accuracy: 0.9515 - val_loss: 0.1295
# Epoch 174/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9364 - loss: 0.0976 - val_accuracy: 0.9431 - val_loss: 0.1541
# Epoch 175/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9332 - loss: 0.0913 - val_accuracy: 0.9465 - val_loss: 0.1417
# Epoch 176/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9467 - loss: 0.0643 - val_accuracy: 0.9576 - val_loss: 0.1230
# Epoch 177/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9487 - loss: 0.0840 - val_accuracy: 0.9637 - val_loss: 0.1058
# Epoch 178/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9520 - loss: 0.0915 - val_accuracy: 0.9565 - val_loss: 0.1288
# Epoch 179/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9476 - loss: 0.0831 - val_accuracy: 0.9526 - val_loss: 0.1346
# Epoch 180/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9551 - loss: 0.0640 - val_accuracy: 0.9520 - val_loss: 0.1314
# Epoch 181/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9525 - loss: 0.0781 - val_accuracy: 0.9459 - val_loss: 0.1507
# Epoch 182/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9486 - loss: 0.0668 - val_accuracy: 0.9498 - val_loss: 0.1323
# Epoch 183/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9563 - loss: 0.0668 - val_accuracy: 0.9671 - val_loss: 0.0901
# Epoch 184/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9624 - loss: 0.0549 - val_accuracy: 0.9649 - val_loss: 0.1163
# Epoch 185/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9581 - loss: 0.0645 - val_accuracy: 0.9615 - val_loss: 0.1165
# Epoch 186/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9588 - loss: 0.0573 - val_accuracy: 0.9654 - val_loss: 0.1067
# Epoch 187/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9560 - loss: 0.0477 - val_accuracy: 0.9504 - val_loss: 0.1440
# Epoch 188/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9550 - loss: 0.0533 - val_accuracy: 0.9660 - val_loss: 0.1016
# Epoch 189/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9630 - loss: 0.0448 - val_accuracy: 0.9649 - val_loss: 0.1042
# Epoch 190/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9599 - loss: 0.0550 - val_accuracy: 0.9654 - val_loss: 0.0994
# Epoch 191/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9621 - loss: 0.0450 - val_accuracy: 0.9637 - val_loss: 0.0914
# Epoch 192/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9539 - loss: 0.0762 - val_accuracy: 0.9610 - val_loss: 0.1056
# Epoch 193/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9488 - loss: 0.0601 - val_accuracy: 0.9353 - val_loss: 0.1671
# Epoch 194/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9415 - loss: 0.0991 - val_accuracy: 0.9526 - val_loss: 0.1209
# Epoch 195/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9588 - loss: 0.0728 - val_accuracy: 0.9637 - val_loss: 0.1009
# Epoch 196/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9584 - loss: 0.0672 - val_accuracy: 0.9526 - val_loss: 0.1237
# Epoch 197/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9568 - loss: 0.0759 - val_accuracy: 0.9721 - val_loss: 0.0700
# Epoch 198/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9583 - loss: 0.0655 - val_accuracy: 0.9604 - val_loss: 0.0961
# Epoch 199/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9591 - loss: 0.0584 - val_accuracy: 0.9626 - val_loss: 0.1024
# Epoch 200/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9622 - loss: 0.0555 - val_accuracy: 0.9688 - val_loss: 0.0810
# Epoch 201/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9627 - loss: 0.0727 - val_accuracy: 0.9660 - val_loss: 0.0916
# Epoch 202/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9538 - loss: 0.0726 - val_accuracy: 0.9532 - val_loss: 0.1227
# Epoch 203/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.9416 - loss: 0.0805 - val_accuracy: 0.9615 - val_loss: 0.0994
# Epoch 204/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9624 - loss: 0.0488 - val_accuracy: 0.9470 - val_loss: 0.1367
# Epoch 205/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9546 - loss: 0.0725 - val_accuracy: 0.9621 - val_loss: 0.1005
# Epoch 206/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9580 - loss: 0.0553 - val_accuracy: 0.9637 - val_loss: 0.0939
# Epoch 207/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9425 - loss: 0.1071 - val_accuracy: 0.9704 - val_loss: 0.0831
# Epoch 208/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9625 - loss: 0.0554 - val_accuracy: 0.9286 - val_loss: 0.1869
# Epoch 209/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9263 - loss: 0.1151 - val_accuracy: 0.9632 - val_loss: 0.1136
# Epoch 210/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9552 - loss: 0.0838 - val_accuracy: 0.9130 - val_loss: 0.2582
# Epoch 211/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9346 - loss: 0.1209 - val_accuracy: 0.9637 - val_loss: 0.0910
# Epoch 212/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9580 - loss: 0.0744 - val_accuracy: 0.9532 - val_loss: 0.1322
# Epoch 213/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9471 - loss: 0.0952 - val_accuracy: 0.9615 - val_loss: 0.0947
# Epoch 214/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9636 - loss: 0.0610 - val_accuracy: 0.9654 - val_loss: 0.0913
# Epoch 215/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9632 - loss: 0.0600 - val_accuracy: 0.9654 - val_loss: 0.0914
# Epoch 216/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9680 - loss: 0.0408 - val_accuracy: 0.9598 - val_loss: 0.1016
# Epoch 217/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9708 - loss: 0.0410 - val_accuracy: 0.9716 - val_loss: 0.0796
# Epoch 218/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9718 - loss: 0.0361 - val_accuracy: 0.9677 - val_loss: 0.0824
# Epoch 219/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9652 - loss: 0.0514 - val_accuracy: 0.9660 - val_loss: 0.0859
# Epoch 220/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9629 - loss: 0.0632 - val_accuracy: 0.9476 - val_loss: 0.1495
# Epoch 221/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9605 - loss: 0.0626 - val_accuracy: 0.9604 - val_loss: 0.1033
# Epoch 222/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9659 - loss: 0.0524 - val_accuracy: 0.9704 - val_loss: 0.0732
# Epoch 223/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9722 - loss: 0.0422 - val_accuracy: 0.9587 - val_loss: 0.1034
# Epoch 224/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9558 - loss: 0.1068 - val_accuracy: 0.9465 - val_loss: 0.1488
# Epoch 225/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8294 - loss: 0.8751 - val_accuracy: 0.9347 - val_loss: 0.1793
# Epoch 226/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9275 - loss: 0.1221 - val_accuracy: 0.9398 - val_loss: 0.1678
# Epoch 227/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9439 - loss: 0.1293 - val_accuracy: 0.9470 - val_loss: 0.1563
# Epoch 228/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9429 - loss: 0.1110 - val_accuracy: 0.9398 - val_loss: 0.1872
# Epoch 229/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9328 - loss: 0.0953 - val_accuracy: 0.9593 - val_loss: 0.1163
# Epoch 230/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9595 - loss: 0.0630 - val_accuracy: 0.9626 - val_loss: 0.1007
# Epoch 231/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9541 - loss: 0.0859 - val_accuracy: 0.9615 - val_loss: 0.1164
# Epoch 232/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9426 - loss: 0.1501 - val_accuracy: 0.9621 - val_loss: 0.1117
# Epoch 233/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9546 - loss: 0.0801 - val_accuracy: 0.9392 - val_loss: 0.1704
# Epoch 234/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9540 - loss: 0.0764 - val_accuracy: 0.9587 - val_loss: 0.1068
# Epoch 235/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9625 - loss: 0.0417 - val_accuracy: 0.9565 - val_loss: 0.1170
# Epoch 236/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9682 - loss: 0.0558 - val_accuracy: 0.9677 - val_loss: 0.1032
# Epoch 237/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9670 - loss: 0.0442 - val_accuracy: 0.9314 - val_loss: 0.2112
# Epoch 238/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9371 - loss: 0.1477 - val_accuracy: 0.9520 - val_loss: 0.1373
# Epoch 239/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9606 - loss: 0.0504 - val_accuracy: 0.9610 - val_loss: 0.1085
# Epoch 240/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9680 - loss: 0.0427 - val_accuracy: 0.9677 - val_loss: 0.0881
# Epoch 241/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9592 - loss: 0.0998 - val_accuracy: 0.9387 - val_loss: 0.1876
# Epoch 242/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9517 - loss: 0.0910 - val_accuracy: 0.9515 - val_loss: 0.1327
# Epoch 243/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9183 - loss: 0.2448 - val_accuracy: 0.9537 - val_loss: 0.1208
# Epoch 244/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9577 - loss: 0.0930 - val_accuracy: 0.9582 - val_loss: 0.1196
# Epoch 245/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9634 - loss: 0.0555 - val_accuracy: 0.9292 - val_loss: 0.2066
# Epoch 246/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9503 - loss: 0.0966 - val_accuracy: 0.9604 - val_loss: 0.1163
# Epoch 247/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9428 - loss: 0.0838 - val_accuracy: 0.9626 - val_loss: 0.1072
# Epoch 248/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9680 - loss: 0.0591 - val_accuracy: 0.9191 - val_loss: 0.2808
# Epoch 249/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9185 - loss: 0.2586 - val_accuracy: 0.9453 - val_loss: 0.1566
# Epoch 250/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9409 - loss: 0.1106 - val_accuracy: 0.9509 - val_loss: 0.1449
# Epoch 251/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9305 - loss: 0.1719 - val_accuracy: 0.9297 - val_loss: 0.2152
# Epoch 252/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9429 - loss: 0.0775 - val_accuracy: 0.9587 - val_loss: 0.1198
# Epoch 253/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9627 - loss: 0.0527 - val_accuracy: 0.9520 - val_loss: 0.1367
# Epoch 254/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9525 - loss: 0.0593 - val_accuracy: 0.9481 - val_loss: 0.1486
# Epoch 255/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9512 - loss: 0.0660 - val_accuracy: 0.9582 - val_loss: 0.1169
# Epoch 256/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9597 - loss: 0.0651 - val_accuracy: 0.9665 - val_loss: 0.0915
# Epoch 257/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - accuracy: 0.9675 - loss: 0.0428 - val_accuracy: 0.9665 - val_loss: 0.0945
# Epoch 258/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9674 - loss: 0.0576 - val_accuracy: 0.9727 - val_loss: 0.0716
# Epoch 259/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9657 - loss: 0.0464 - val_accuracy: 0.9671 - val_loss: 0.0855
# Epoch 260/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9719 - loss: 0.0605 - val_accuracy: 0.9704 - val_loss: 0.0789
# Epoch 261/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9666 - loss: 0.0313 - val_accuracy: 0.9537 - val_loss: 0.1261
# Epoch 262/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9657 - loss: 0.0412 - val_accuracy: 0.9610 - val_loss: 0.1104
# Epoch 263/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9622 - loss: 0.0525 - val_accuracy: 0.9693 - val_loss: 0.0841
# Epoch 264/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9741 - loss: 0.0270 - val_accuracy: 0.9459 - val_loss: 0.1527
# Epoch 265/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9614 - loss: 0.0424 - val_accuracy: 0.9688 - val_loss: 0.0843
# Epoch 266/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9548 - loss: 0.0578 - val_accuracy: 0.9593 - val_loss: 0.1162
# Epoch 267/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9633 - loss: 0.0505 - val_accuracy: 0.9610 - val_loss: 0.1060
# Epoch 268/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9595 - loss: 0.0510 - val_accuracy: 0.9420 - val_loss: 0.1503
# Epoch 269/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9571 - loss: 0.0927 - val_accuracy: 0.9665 - val_loss: 0.0793
# Epoch 270/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9699 - loss: 0.0351 - val_accuracy: 0.9743 - val_loss: 0.0726
# Epoch 271/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9645 - loss: 0.0767 - val_accuracy: 0.9688 - val_loss: 0.0789
# Epoch 272/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9677 - loss: 0.0517 - val_accuracy: 0.9253 - val_loss: 0.1960
# Epoch 273/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9562 - loss: 0.0564 - val_accuracy: 0.9554 - val_loss: 0.1206
# Epoch 274/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9535 - loss: 0.1071 - val_accuracy: 0.9571 - val_loss: 0.1165
# Epoch 275/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9620 - loss: 0.0330 - val_accuracy: 0.9610 - val_loss: 0.0898
# Epoch 276/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9717 - loss: 0.0473 - val_accuracy: 0.9632 - val_loss: 0.0925
# Epoch 277/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.9679 - loss: 0.0475 - val_accuracy: 0.9649 - val_loss: 0.0963
# Epoch 278/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9586 - loss: 0.0505 - val_accuracy: 0.9693 - val_loss: 0.0844
# Epoch 279/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9706 - loss: 0.0392 - val_accuracy: 0.9665 - val_loss: 0.0892
# Epoch 280/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9728 - loss: 0.0342 - val_accuracy: 0.9665 - val_loss: 0.0919
# Epoch 281/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9681 - loss: 0.0400 - val_accuracy: 0.9665 - val_loss: 0.1001
# Epoch 282/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9685 - loss: 0.0398 - val_accuracy: 0.9671 - val_loss: 0.0840
# Epoch 283/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9627 - loss: 0.0599 - val_accuracy: 0.9749 - val_loss: 0.0620
# Epoch 284/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9661 - loss: 0.0499 - val_accuracy: 0.9426 - val_loss: 0.1711
# Epoch 285/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9339 - loss: 0.0830 - val_accuracy: 0.9548 - val_loss: 0.1289
# Epoch 286/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9543 - loss: 0.0452 - val_accuracy: 0.9381 - val_loss: 0.1960
# Epoch 287/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9540 - loss: 0.0542 - val_accuracy: 0.9504 - val_loss: 0.1390
# Epoch 288/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.9408 - loss: 0.1916 - val_accuracy: 0.9615 - val_loss: 0.0965
# Epoch 289/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9443 - loss: 0.1347 - val_accuracy: 0.9587 - val_loss: 0.1129
# Epoch 290/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9457 - loss: 0.1431 - val_accuracy: 0.9526 - val_loss: 0.1261
# Epoch 291/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9595 - loss: 0.0516 - val_accuracy: 0.9593 - val_loss: 0.1173
# Epoch 292/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9631 - loss: 0.0530 - val_accuracy: 0.9509 - val_loss: 0.1306
# Epoch 293/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9657 - loss: 0.0423 - val_accuracy: 0.9665 - val_loss: 0.1010
# Epoch 294/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.9649 - loss: 0.0687 - val_accuracy: 0.9543 - val_loss: 0.1336
# Epoch 295/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.9608 - loss: 0.0609 - val_accuracy: 0.9693 - val_loss: 0.0771
# Epoch 296/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9696 - loss: 0.0368 - val_accuracy: 0.9476 - val_loss: 0.1381
# Epoch 297/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9673 - loss: 0.0369 - val_accuracy: 0.9671 - val_loss: 0.0870
# Epoch 298/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9711 - loss: 0.0356 - val_accuracy: 0.9632 - val_loss: 0.1001
# Epoch 299/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9649 - loss: 0.0418 - val_accuracy: 0.9626 - val_loss: 0.0910
# Epoch 300/300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9605 - loss: 0.0576 - val_accuracy: 0.9626 - val_loss: 0.1025

# %%
plt.figure(figsize=[14,10])
plt.subplot(211)
plt.plot(history.history['loss'],'#d62728',linewidth=3.0)
plt.plot(history.history['val_loss'],'#1f77b4',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Accuracy Curves
plt.figure(figsize=[14,10])
plt.subplot(212)
plt.plot(history.history['accuracy'],'#d62728',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'#1f77b4',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9644 - loss: 0.1032
# Test loss: 0.10254263132810593
# Test accuracy: 0.9626324772834778

# %%
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix

# %%
predictions = model.predict(x_test, verbose=1)
y_true, y_pred = [],[]
classes = encoder.classes_
for idx, prediction in enumerate(predictions):
    y_true.append(classes[np.argmax(y_test[idx])])
    y_pred.append(classes[np.argmax(prediction)])
print(classification_report(y_pred, y_true))
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#                 precision    recall  f1-score   support
#
#         Asthma       1.00      1.00      1.00         2
# Bronchiectasis       0.97      0.94      0.96        35
#  Bronchiolitis       0.76      1.00      0.87        13
#           COPD       0.96      1.00      0.98      1517
#        Healthy       0.93      0.81      0.87        64
#           LRTI       1.00      0.67      0.80         3
#      Pneumonia       0.99      0.62      0.76       115
#           URTI       0.97      0.86      0.92        44
#
#       accuracy                           0.96      1793
#      macro avg       0.95      0.86      0.89      1793
#   weighted avg       0.96      0.96      0.96      1793

# %%
classes
# Out:
# array(['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy',
#        'LRTI', 'Pneumonia', 'URTI'], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics
# Plot the confusion matrix
confusion_matrix = metrics.confusion_matrix(y_true, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix =confusion_matrix, display_labels=classes)
cm_display.plot()
plt.show()

# %%
model_name = "lung.h5"
model.save(model_name)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
model = load_model("lung.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from tensorflow.keras.models import load_model
import numpy as np
classify_file = R"C:\Users\vd327\Downloads\ICBHI\ICBHI\ICBHI_final_database\\113_1b1_Ll_sc_Litt3200.wav"
test_x = []
test_x.append(extract_features(classify_file,0.5))
test_x = np.asarray(test_x)
test_x = test_x.reshape(test_x.shape[0], test_x.shape[1], test_x.shape[2], 1)
pred = model.predict(test_x,verbose=1)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# [[0.0000000e+00 6.6962711e-14 3.2779778e-20 1.0000000e+00 3.4419290e-35
#   0.0000000e+00 2.4651007e-16 7.1274109e-10]]

# %%
pred_class = model.predict(test_x)
index = np.argmax(pred_class, axis=1)
print(classes[index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['COPD']

# %%
actual = diagnosis.loc[diagnosis['ID'] == 113]
actual
# Out:
#      ID Symptom
# 12  113    COPD

# %%
from tensorflow.keras.applications import vgg16, resnet
from tensorflow.keras.models import Model
import tensorflow.keras

# %%
vgg = vgg16.VGG16(include_top=False, weights=None, input_shape=(x_train.shape[1],x_train.shape[2],x_train.shape[3]))
# adding our own custom made Flatten layer on top of pretrained vgg16 Conv␣layers
output = vgg.layers[-1].output
output = keras.layers.Flatten()(output)
vgg_model = Model(vgg.input, output)

# %%
import pandas as pd
pd.set_option('max_colwidth', 1)
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                      Layer Type     Layer Name  \
# 0   <InputLayer name=input_layer_1, built=True>  input_layer_1
# 1   <Conv2D name=block1_conv1, built=True>       block1_conv1
# 2   <Conv2D name=block1_conv2, built=True>       block1_conv2
# 3   <MaxPooling2D name=block1_pool, built=True>  block1_pool
# 4   <Conv2D name=block2_conv1, built=True>       block2_conv1
# 5   <Conv2D name=block2_conv2, built=True>       block2_conv2
# 6   <MaxPooling2D name=block2_pool, built=True>  block2_pool
# 7   <Conv2D name=block3_conv1, built=True>       block3_conv1
# 8   <Conv2D name=block3_conv2, built=True>       block3_conv2
# 9   <Conv2D name=block3_conv3, built=True>       block3_conv3
# 10  <MaxPooling2D name=block3_pool, built=True>  block3_pool
# 11  <Conv2D name=block4_conv1, built=True>       block4_conv1
# 12  <Conv2D name=block4_conv2, built=True>       block4_conv2
# 13  <Conv2D name=block4_conv3, built=True>       block4_conv3
# 14  <MaxPooling2D name=block4_pool, built=True>  block4_pool
# 15  <Conv2D name=block5_conv1, built=True>       block5_conv1
# 16  <Conv2D name=block5_conv2, built=True>       block5_conv2
# 17  <Conv2D name=block5_conv3, built=True>       block5_conv3
# 18  <MaxPooling2D name=block5_pool, built=True>  block5_pool
# 19  <Flatten name=flatten, built=True>           flatten
#
#     Layer Trainable
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True
# 5   True
# 6   True
# 7   True
# 8   True
# 9   True
# 10  True
# 11  True
# 12  True
# 13  True
# 14  True
# 15  True
# 16  True
# 17  True
# 18  True
# 19  True

# %%
modelvgg = Sequential()
modelvgg.add(vgg_model)
modelvgg.add(Dense(512, activation='relu'))
modelvgg.add(Dense(len(encoder.classes_), activation='softmax'))
modelvgg.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ functional_28 (Functional)           │ (None, 2048)                │      14,713,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │           4,104 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,766,728 (60.15 MB)
#  Trainable params: 15,766,728 (60.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
modelvgg.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

# %%
history_vgg = modelvgg.fit(x_train, y_train,
    batch_size=128,
    epochs=1,
    validation_data=(x_test, y_test),
    shuffle=True)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - accuracy: 0.8721 - loss: 0.7236 - val_accuracy: 0.8762 - val_loss: 0.4428

# %%
plt.figure(figsize=[14,10])
plt.subplot(211)
plt.plot(history_vgg.history['loss'],'#d62728',linewidth=3.0)
plt.plot(history_vgg.history['val_loss'],'#1f77b4',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Accuracy Curves
plt.figure(figsize=[14,10])
plt.subplot(212)
plt.plot(history_vgg.history['accuracy'],'#d62728',linewidth=3.0)
plt.plot(history_vgg.history['val_accuracy'],'#1f77b4',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
scores = modelvgg.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 14s 242ms/step - accuracy: 0.8717 - loss: 0.4472
# Test loss: 0.44281357526779175
# Test accuracy: 0.8761851787567139

# %%
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix

# %%
predictions = modelvgg.predict(x_test, verbose=1)
y_true, y_pred = [],[]
classes = encoder.classes_
for idx, prediction in enumerate(predictions):
    y_true.append(classes[np.argmax(y_test[idx])])
    y_pred.append(classes[np.argmax(prediction)])
print(classification_report(y_pred, y_true))
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step
#                 precision    recall  f1-score   support
#
#         Asthma       0.00      0.00      0.00         0
# Bronchiectasis       0.00      0.00      0.00         0
#  Bronchiolitis       0.00      0.00      0.00         0
#           COPD       1.00      0.88      0.93      1793
#        Healthy       0.00      0.00      0.00         0
#           LRTI       0.00      0.00      0.00         0
#      Pneumonia       0.00      0.00      0.00         0
#           URTI       0.00      0.00      0.00         0
#
#       accuracy                           0.88      1793
#      macro avg       0.12      0.11      0.12      1793
#   weighted avg       1.00      0.88      0.93      1793
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
classes
# Out:
# array(['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy',
#        'LRTI', 'Pneumonia', 'URTI'], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics
# Check which classes are confused.
confusion_matrix = metrics.confusion_matrix(y_true, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix =confusion_matrix, display_labels=classes)
cm_display.plot()
plt.show()
